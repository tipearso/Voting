# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from functools import reduce
# %matplotlib inline

# %%
#need to make sure you keep all of your source data close at hand so you can cite your sources....

# %% [markdown]
# reading in my data on elections from 1976..each table represents data for the named elections from the years in the comments

# %%
#US House 1976-2018
house = pd.read_csv('../data/1976-2018-house3.csv')

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29636 entries, 0 to 29635
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            29636 non-null  int64
#  1   state           29636 non-null  object
#  2   state_po        29636 non-null  object
#  3   state_fips      29636 non-null  int64
#  4   state_cen       29636 non-null  int64
#  5   state_ic        29636 non-null  int64
#  6   office          29636 non-null  object
#  7   district        29636 non-null  int64
#  8   stage           29606 non-null  object
#  9   runoff          20980 non-null  object
#  10  special         29636 non-null  bool
#  11  candidate       27516 non-null  object
#  12  party           26214 non-null  object
#  13  writein         29636 non-null  bool
#  14  mode            29636 non-null  object
#  15  candidatevotes  29636 non-null  int64
#  16  totalvotes      29636 non-null  int64
#  17  unofficial      29636 non-null  bool
#  18  version         29636 non-null  int64
#  19  fusion_ticket   29636 non-null  bool
# dtypes: bool(4), int64(8), object(8)
# memory usage: 3.7+ MB

# %%
house.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic    office  \
# 0  1976  ALABAMA       AL           1         63        41  US HOUSE
# 1  1976  ALABAMA       AL           1         63        41  US HOUSE
# 2  1976  ALABAMA       AL           1         63        41  US HOUSE
# 3  1976  ALABAMA       AL           1         63        41  US HOUSE
# 4  1976  ALABAMA       AL           1         63        41  US HOUSE
#
#    district stage runoff  special         candidate       party  writein  \
# 0         1   gen  False    False    BILL DAVENPORT    DEMOCRAT    False
# 1         1   gen  False    False      JACK EDWARDS  REPUBLICAN    False
# 2         1   gen  False    False               NaN         NaN     True
# 3         2   gen  False    False  J. CAROLE KEAHEY    DEMOCRAT    False
# 4         2   gen  False    False               NaN         NaN     True
#
#     mode  candidatevotes  totalvotes  unofficial   version  fusion_ticket
# 0  TOTAL           58906      157170       False  20201202          False
# 1  TOTAL           98257      157170       False  20201202          False
# 2  TOTAL               7      157170       False  20201202          False
# 3  TOTAL           66288      156362       False  20201202          False
# 4  TOTAL               5      156362       False  20201202          False

# %%
house.tail()
# Out:
#        year     state state_po  state_fips  state_cen  state_ic    office  \
# 29631  2018  MARYLAND       MD          24         52        52  US HOUSE
# 29632  2018  MARYLAND       MD          24         52        52  US HOUSE
# 29633  2018  MARYLAND       MD          24         52        52  US HOUSE
# 29634  2018  MARYLAND       MD          24         52        52  US HOUSE
# 29635  2018  MARYLAND       MD          24         52        52  US HOUSE
#
#        district stage runoff  special     candidate        party  writein  \
# 29631         7   gen    NaN    False           NaN          NaN     True
# 29632         8   gen    NaN    False  JAMIE RASKIN     DEMOCRAT    False
# 29633         8   gen    NaN    False  JASEN WUNDER  LIBERTARIAN    False
# 29634         8   gen    NaN    False    JOHN WALSH   REPUBLICAN    False
# 29635         8   gen    NaN    False           NaN          NaN     True
#
#         mode  candidatevotes  totalvotes  unofficial   version  fusion_ticket
# 29631  TOTAL             272      264710       False  20201202          False
# 29632  TOTAL          217679      319330       False  20201202          False
# 29633  TOTAL            4853      319330       False  20201202          False
# 29634  TOTAL           96525      319330       False  20201202          False
# 29635  TOTAL             273      319330       False  20201202          False

# %%
#US Senate 1976-2020
senate = pd.read_csv('../data/1976-2020-senate.csv')

# %%
senate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3629 entries, 0 to 3628
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              3629 non-null   int64
#  1   state             3629 non-null   object
#  2   state_po          3629 non-null   object
#  3   state_fips        3629 non-null   int64
#  4   state_cen         3629 non-null   int64
#  5   state_ic          3629 non-null   int64
#  6   office            3629 non-null   object
#  7   district          3629 non-null   object
#  8   stage             3629 non-null   object
#  9   special           3629 non-null   bool
#  10  candidate         3206 non-null   object
#  11  party_detailed    3030 non-null   object
#  12  writein           3629 non-null   bool
#  13  mode              3629 non-null   object
#  14  candidatevotes    3629 non-null   int64
#  15  totalvotes        3629 non-null   int64
#  16  unofficial        3629 non-null   bool
#  17  version           3629 non-null   int64
#  18  party_simplified  3629 non-null   object
# dtypes: bool(3), int64(7), object(9)
# memory usage: 464.4+ KB

# %%
senate.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic     office  \
# 0  1976  ARIZONA       AZ           4         86        61  US SENATE
# 1  1976  ARIZONA       AZ           4         86        61  US SENATE
# 2  1976  ARIZONA       AZ           4         86        61  US SENATE
# 3  1976  ARIZONA       AZ           4         86        61  US SENATE
# 4  1976  ARIZONA       AZ           4         86        61  US SENATE
#
#     district stage  special            candidate party_detailed  writein  \
# 0  statewide   gen    False          SAM STEIGER     REPUBLICAN    False
# 1  statewide   gen    False  WM. MATHEWS FEIGHAN    INDEPENDENT    False
# 2  statewide   gen    False     DENNIS DECONCINI       DEMOCRAT    False
# 3  statewide   gen    False        ALLAN NORWITZ    LIBERTARIAN    False
# 4  statewide   gen    False            BOB FIELD    INDEPENDENT    False
#
#     mode  candidatevotes  totalvotes  unofficial   version party_simplified
# 0  total          321236      741210       False  20210114       REPUBLICAN
# 1  total            1565      741210       False  20210114            OTHER
# 2  total          400334      741210       False  20210114         DEMOCRAT
# 3  total            7310      741210       False  20210114      LIBERTARIAN
# 4  total           10765      741210       False  20210114            OTHER

# %%
senate.tail()
# Out:
#       year    state state_po  state_fips  state_cen  state_ic     office  \
# 3624  2020  WYOMING       WY          56         83        68  US SENATE
# 3625  2021  GEORGIA       GA          13         58        44  US SENATE
# 3626  2021  GEORGIA       GA          13         58        44  US SENATE
# 3627  2021  GEORGIA       GA          13         58        44  US SENATE
# 3628  2021  GEORGIA       GA          13         58        44  US SENATE
#
#        district   stage  special        candidate party_detailed  writein  \
# 3624  statewide     gen    False      UNDER VOTES            NaN    False
# 3625  statewide  runoff     True   KELLY LOEFFLER     REPUBLICAN    False
# 3626  statewide  runoff     True  RAPHAEL WARNOCK       DEMOCRAT    False
# 3627  statewide  runoff    False  DAVID A. PERDUE     REPUBLICAN    False
# 3628  statewide  runoff    False       JON OSSOFF       DEMOCRAT    False
#
#        mode  candidatevotes  totalvotes  unofficial   version party_simplified
# 3624  total            6401      278503       False  20210114            OTHER
# 3625  total         2194848     4483294        True  20210114       REPUBLICAN
# 3626  total         2288446     4483294        True  20210114         DEMOCRAT
# 3627  total         2213979     4483241        True  20210114       REPUBLICAN
# 3628  total         2269262     4483241        True  20210114         DEMOCRAT

# %%
#US president 1976-2020
president = pd.read_csv('../data/1976-2020-president.csv')

# %%
president.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4287 entries, 0 to 4286
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              4287 non-null   int64
#  1   state             4287 non-null   object
#  2   state_po          4287 non-null   object
#  3   state_fips        4287 non-null   int64
#  4   state_cen         4287 non-null   int64
#  5   state_ic          4287 non-null   int64
#  6   office            4287 non-null   object
#  7   candidate         4000 non-null   object
#  8   party_detailed    3831 non-null   object
#  9   writein           4284 non-null   object
#  10  candidatevotes    4287 non-null   int64
#  11  totalvotes        4287 non-null   int64
#  12  version           4287 non-null   int64
#  13  notes             0 non-null      float64
#  14  party_simplified  4287 non-null   object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 502.5+ KB

# %%
president.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  1976  ALABAMA       AL           1         63        41  US PRESIDENT
#
#                  candidate              party_detailed writein  \
# 0            CARTER, JIMMY                    DEMOCRAT   False
# 1             FORD, GERALD                  REPUBLICAN   False
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                HALL, GUS         COMMUNIST PARTY USE   False
#
#    candidatevotes  totalvotes   version  notes party_simplified
# 0          659170     1182850  20210113    NaN         DEMOCRAT
# 1          504070     1182850  20210113    NaN       REPUBLICAN
# 2            9198     1182850  20210113    NaN            OTHER
# 3            6669     1182850  20210113    NaN            OTHER
# 4            1954     1182850  20210113    NaN            OTHER

# %%
president.tail()
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
#           candidate party_detailed writein  candidatevotes  totalvotes  \
# 4282  JORGENSEN, JO    LIBERTARIAN   False            5768      278503
# 4283  PIERCE, BROCK    INDEPENDENT   False            2208      278503
# 4284            NaN            NaN    True            1739      278503
# 4285      OVERVOTES            NaN   False             279      278503
# 4286     UNDERVOTES            NaN   False            1459      278503
#
#        version  notes party_simplified
# 4282  20210113    NaN      LIBERTARIAN
# 4283  20210113    NaN            OTHER
# 4284  20210113    NaN            OTHER
# 4285  20210113    NaN            OTHER
# 4286  20210113    NaN            OTHER

# %%
#county returns president 2000-2016
county_pres = pd.read_csv('../data/countypres_2000-2016.csv')

# %%
county_pres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50524 entries, 0 to 50523
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            50524 non-null  int64
#  1   state           50524 non-null  object
#  2   state_po        50460 non-null  object
#  3   county          50524 non-null  object
#  4   FIPS            50476 non-null  float64
#  5   office          50524 non-null  object
#  6   candidate       50524 non-null  object
#  7   party           34735 non-null  object
#  8   candidatevotes  50120 non-null  float64
#  9   totalvotes      50524 non-null  int64
#  10  version         50524 non-null  int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 4.2+ MB

# %%
county_pres.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          4942.0       17208  20191203
# 1  republican         11993.0       17208  20191203
# 2       green           160.0       17208  20191203
# 3         NaN           113.0       17208  20191203
# 4    democrat         13997.0       56480  20191203

# %%
county_pres.tail()
# Out:
#        year   state state_po       county    FIPS     office        candidate  \
# 50519  2016  Alaska       AK  District 40  2040.0  President     Donald Trump
# 50520  2016  Alaska       AK  District 40  2040.0  President            Other
# 50521  2016  Alaska      NaN  District 99  2099.0  President  Hillary Clinton
# 50522  2016  Alaska      NaN  District 99  2099.0  President     Donald Trump
# 50523  2016  Alaska      NaN  District 99  2099.0  President            Other
#
#             party  candidatevotes  totalvotes   version
# 50519  republican          1377.0        4610  20191203
# 50520         NaN           895.0        4610  20191203
# 50521    democrat           274.0        5056  20191203
# 50522  republican            40.0        5056  20191203
# 50523         NaN            28.0        5056  20191203

# %% [markdown]
# reading in census data for elections by year

# %%
reg_sex_state_2010 = pd.read_excel('../data/registration_race_sex_state_2010.xls',header = 2)

# %%
#this is going to need some cleaning....cool.
reg_sex_state_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   STATE                         59 non-null     object
#  1   Unnamed: 1                    572 non-null    object
#  2   Total Population              572 non-null    float64
#  3   Total Citizen Population      572 non-null    object
#  4   Total registered              572 non-null    object
#  5   Percent registered
# (Total)    572 non-null    object
#  6   Margin of Error1              572 non-null    object
#  7   Percent registered
# (Citizen)  572 non-null    object
#  8   Margin of Error1.1            572 non-null    object
#  9   Total voted                   572 non-null    object
#  10  Percent voted
# (Total)         572 non-null    object
#  11  Margin of Error1.2            572 non-null    object
#  12  Percent voted
# (Citizen)       572 non-null    object
#  13  Margin of Error1.3            572 non-null    object
# dtypes: float64(1), object(13)
# memory usage: 63.8+ KB

# %%
#population of 18yo +in thousands 

reg_sex_state_2010.head(15)
# Out:
#       STATE                     Unnamed: 1  Total Population  \
# 0        US                          Total          229690.0
# 1       NaN                           Male          111098.0
# 2       NaN                         Female          118592.0
# 3       NaN                    White alone          185804.0
# 4       NaN       White non-Hispanic alone          155680.0
# 5       NaN                    Black alone           27396.0
# 6       NaN                    Asian alone           11049.0
# 7       NaN         Hispanic (of any race)           32457.0
# 8       NaN  White alone or in combination          188616.0
# 9       NaN  Black alone or in combination           28414.0
# 10      NaN  Asian alone or in combination           11679.0
# 11  ALABAMA                          Total            3526.0
# 12      NaN                           Male            1652.0
# 13      NaN                         Female            1873.0
# 14      NaN                    White alone            2611.0
#
#    Total Citizen Population Total registered Percent registered\n(Total)  \
# 0                    210800           137263                        59.8
# 1                    101279            64337                        57.9
# 2                    109521            72926                        61.5
# 3                    172447           114482                        61.6
# 4                    152929           104316                          67
# 5                     25632            16101                        58.8
# 6                      7639             3765                        34.1
# 7                     21285            10982                        33.8
# 8                    175090           116115                        61.6
# 9                     26602            16684                        58.7
# 10                     8246             4136                        35.4
# 11                     3420             2224                        63.1
# 12                     1580              989                        59.8
# 13                     1840             1235                        65.9
# 14                     2521             1612                        61.7
#
#    Margin of Error1 Percent registered\n(Citizen) Margin of Error1.1  \
# 0               0.3                          65.1                0.3
# 1               0.4                          63.5                0.4
# 2               0.4                          66.6                0.4
# 3               0.3                          66.4                0.3
# 4               0.3                          68.2                0.3
# 5                 1                          62.8                  1
# 6               1.6                          49.3                  2
# 7               1.2                          51.6                1.5
# 8               0.3                          66.3                0.3
# 9                 1                          62.7                  1
# 10              1.6                          50.2                  2
# 11              2.4                            65                2.4
# 12              3.6                          62.6                3.6
# 13              3.2                          67.1                3.2
# 14              2.8                            64                2.8
#
#    Total voted Percent voted\n(Total) Margin of Error1.2  \
# 0        95987                   41.8                0.3
# 1        45392                   40.9                0.4
# 2        50595                   42.7                0.4
# 3        80554                   43.4                0.3
# 4        74372                   47.8                0.4
# 5        11149                   40.7                  1
# 6         2354                   21.3                1.4
# 7         6646                   20.5                  1
# 8        81614                   43.3                0.3
# 9        11498                   40.5                  1
# 10        2615                   22.4                1.4
# 11        1509                   42.8                2.5
# 12         664                   40.2                3.6
# 13         845                   45.1                3.4
# 14        1097                     42                2.8
#
#    Percent voted\n(Citizen) Margin of Error1.3
# 0                      45.5                0.3
# 1                      44.8                0.4
# 2                      46.2                0.4
# 3                      46.7                0.3
# 4                      48.6                0.4
# 5                      43.5                1.1
# 6                      30.8                1.9
# 7                      31.2                1.4
# 8                      46.6                0.3
# 9                      43.2                  1
# 10                     31.7                1.8
# 11                     44.1                2.5
# 12                       42                3.7
# 13                     45.9                3.4
# 14                     43.5                2.9

# %%
#bottom of table contains some (un)helpful info that should have been in a readme file. 

reg_sex_state_2010.tail(100)
# Out:
#                                                  STATE  \
# 482                                                NaN
# 483                                                NaN
# 484                                              TEXAS
# 485                                                NaN
# 486                                                NaN
# ..                                                 ...
# 577  Federal surveys now give respondents the optio...
# 578      A dash '-' represents zero or rounds to zero.
# 579  The symbol (B) means that the base is less tha...
# 580
# 581  Source: U.S. Census Bureau, Current Population...
#
#                         Unnamed: 1  Total Population Total Citizen Population  \
# 482  Black alone or in combination             722.0                      672
# 483  Asian alone or in combination              77.0                       45
# 484                          Total           17847.0                    15403
# 485                           Male            8742.0                     7430
# 486                         Female            9105.0                     7973
# ..                             ...               ...                      ...
# 577                            NaN               NaN                      NaN
# 578                            NaN               NaN                      NaN
# 579                            NaN               NaN                      NaN
# 580                            NaN               NaN                      NaN
# 581                            NaN               NaN                      NaN
#
#     Total registered Percent registered\n(Total) Margin of Error1  \
# 482              415                        57.4              6.7
# 483               13                        17.4             16.3
# 484             9493                        53.2              1.1
# 485             4438                        50.8              1.6
# 486             5054                        55.5              1.6
# ..               ...                         ...              ...
# 577              NaN                         NaN              NaN
# 578              NaN                         NaN              NaN
# 579              NaN                         NaN              NaN
# 580              NaN                         NaN              NaN
# 581              NaN                         NaN              NaN
#
#     Percent registered\n(Citizen) Margin of Error1.1 Total voted  \
# 482                          61.7                6.8         242
# 483                          29.7               25.7           6
# 484                          61.6                1.2        5600
# 485                          59.7                1.7        2631
# 486                          63.4                1.6        2969
# ..                            ...                ...         ...
# 577                           NaN                NaN         NaN
# 578                           NaN                NaN         NaN
# 579                           NaN                NaN         NaN
# 580                           NaN                NaN         NaN
# 581                           NaN                NaN         NaN
#
#     Percent voted\n(Total) Margin of Error1.2 Percent voted\n(Citizen)  \
# 482                   33.5                6.4                       36
# 483                    8.3               11.9                     14.2
# 484                   31.4                  1                     36.4
# 485                   30.1                1.5                     35.4
# 486                   32.6                1.5                     37.2
# ..                     ...                ...                      ...
# 577                    NaN                NaN                      NaN
# 578                    NaN                NaN                      NaN
# 579                    NaN                NaN                      NaN
# 580                    NaN                NaN                      NaN
# 581                    NaN                NaN                      NaN
#
#     Margin of Error1.3
# 482                6.7
# 483               19.7
# 484                1.2
# 485                1.7
# 486                1.6
# ..                 ...
# 577                NaN
# 578                NaN
# 579                NaN
# 580                NaN
# 581                NaN
#
# [100 rows x 14 columns]

# %%
#tx voting population 18years+

tx_reg_2010 = pd.concat([reg_sex_state_2010.iloc[:11,:],reg_sex_state_2010.iloc[484:495,:]],axis = 0)

# %% [markdown]
# I messed around with the code below trying to set the header...until I found an argument to put into the read_excel function...which I thought worked like a dream but it's currently not working the way I want every time I load it...must be something with my notebook

# %%
#tx voting population 18years+

# tx_reg_2010.columns = tx_reg_2010.iloc[1]
# tx_reg_clean = tx_reg_2010.drop(tx_reg_2010.index[1], axis = 0)

# tx_reg_2010.drop(tx_reg_2010.iloc[:1,:], axis = 0)

# %%
tx_reg_2010 = tx_reg_2010.rename(columns = {'Unnamed: 1': 'Race/Gender'})

# %%
tx_reg_2010
# Out:
#      STATE                    Race/Gender  Total Population  \
# 0       US                          Total          229690.0
# 1      NaN                           Male          111098.0
# 2      NaN                         Female          118592.0
# 3      NaN                    White alone          185804.0
# 4      NaN       White non-Hispanic alone          155680.0
# 5      NaN                    Black alone           27396.0
# 6      NaN                    Asian alone           11049.0
# 7      NaN         Hispanic (of any race)           32457.0
# 8      NaN  White alone or in combination          188616.0
# 9      NaN  Black alone or in combination           28414.0
# 10     NaN  Asian alone or in combination           11679.0
# 484  TEXAS                          Total           17847.0
# 485    NaN                           Male            8742.0
# 486    NaN                         Female            9105.0
# 487    NaN                    White alone           14741.0
# 488    NaN       White non-Hispanic alone            8452.0
# 489    NaN                    Black alone            2060.0
# 490    NaN                    Asian alone             798.0
# 491    NaN         Hispanic (of any race)            6403.0
# 492    NaN  White alone or in combination           14914.0
# 493    NaN  Black alone or in combination            2114.0
# 494    NaN  Asian alone or in combination             802.0
#
#     Total Citizen Population Total registered Percent registered\n(Total)  \
# 0                     210800           137263                        59.8
# 1                     101279            64337                        57.9
# 2                     109521            72926                        61.5
# 3                     172447           114482                        61.6
# 4                     152929           104316                          67
# 5                      25632            16101                        58.8
# 6                       7639             3765                        34.1
# 7                      21285            10982                        33.8
# 8                     175090           116115                        61.6
# 9                      26602            16684                        58.7
# 10                      8246             4136                        35.4
# 484                    15403             9493                        53.2
# 485                     7430             4438                        50.8
# 486                     7973             5054                        55.5
# 487                    12609             7858                        53.3
# 488                     8329             5571                        65.9
# 489                     1993             1242                        60.3
# 490                      567              262                        32.9
# 491                     4376             2334                        36.5
# 492                    12774             7966                        53.4
# 493                     2047             1252                        59.2
# 494                      572              267                        33.3
#
#     Margin of Error1 Percent registered\n(Citizen) Margin of Error1.1  \
# 0                0.3                          65.1                0.3
# 1                0.4                          63.5                0.4
# 2                0.4                          66.6                0.4
# 3                0.3                          66.4                0.3
# 4                0.3                          68.2                0.3
# 5                  1                          62.8                  1
# 6                1.6                          49.3                  2
# 7                1.2                          51.6                1.5
# 8                0.3                          66.3                0.3
# 9                  1                          62.7                  1
# 10               1.6                          50.2                  2
# 484              1.1                          61.6                1.2
# 485              1.6                          59.7                1.7
# 486              1.6                          63.4                1.6
# 487              1.2                          62.3                1.3
# 488              1.6                          66.9                1.6
# 489              3.9                          62.3                  4
# 490              6.3                          46.3                  8
# 491              2.9                          53.3                3.6
# 492              1.2                          62.4                1.3
# 493              3.9                          61.2                3.9
# 494              6.3                          46.7                  8
#
#     Total voted Percent voted\n(Total) Margin of Error1.2  \
# 0         95987                   41.8                0.3
# 1         45392                   40.9                0.4
# 2         50595                   42.7                0.4
# 3         80554                   43.4                0.3
# 4         74372                   47.8                0.4
# 5         11149                   40.7                  1
# 6          2354                   21.3                1.4
# 7          6646                   20.5                  1
# 8         81614                   43.3                0.3
# 9         11498                   40.5                  1
# 10         2615                   22.4                1.4
# 484        5600                   31.4                  1
# 485        2631                   30.1                1.5
# 486        2969                   32.6                1.5
# 487        4631                   31.4                1.2
# 488        3645                   43.1                1.6
# 489         770                   37.4                3.9
# 490         126                   15.8                4.9
# 491        1012                   15.8                2.2
# 492        4697                   31.5                1.1
# 493         773                   36.5                3.8
# 494         131                   16.3                  5
#
#     Percent voted\n(Citizen) Margin of Error1.3
# 0                       45.5                0.3
# 1                       44.8                0.4
# 2                       46.2                0.4
# 3                       46.7                0.3
# 4                       48.6                0.4
# 5                       43.5                1.1
# 6                       30.8                1.9
# 7                       31.2                1.4
# 8                       46.6                0.3
# 9                       43.2                  1
# 10                      31.7                1.8
# 484                     36.4                1.2
# 485                     35.4                1.7
# 486                     37.2                1.6
# 487                     36.7                1.3
# 488                     43.8                1.6
# 489                     38.7                  4
# 490                     22.2                6.7
# 491                     23.1                  3
# 492                     36.8                1.3
# 493                     37.7                3.9
# 494                     22.9                6.7

# %%
###Not sure I'm going to use all of above but I have it....

# %% [markdown]
# reading in TX County Census data 2010-2019

# %% [markdown]
# first age data:

# %%
tx_census_age = pd.read_csv('../data/TX_county_census_data.csv')

# %%
tx_census_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3048 entries, 0 to 3047
# Data columns (total 96 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SUMLEV           3048 non-null   int64
#  1   STATE            3048 non-null   int64
#  2   COUNTY           3048 non-null   int64
#  3   STNAME           3048 non-null   object
#  4   CTYNAME          3048 non-null   object
#  5   YEAR             3048 non-null   int64
#  6   POPESTIMATE      3048 non-null   int64
#  7   POPEST_MALE      3048 non-null   int64
#  8   POPEST_FEM       3048 non-null   int64
#  9   UNDER5_TOT       3048 non-null   int64
#  10  UNDER5_MALE      3048 non-null   int64
#  11  UNDER5_FEM       3048 non-null   int64
#  12  AGE513_TOT       3048 non-null   int64
#  13  AGE513_MALE      3048 non-null   int64
#  14  AGE513_FEM       3048 non-null   int64
#  15  AGE1417_TOT      3048 non-null   int64
#  16  AGE1417_MALE     3048 non-null   int64
#  17  AGE1417_FEM      3048 non-null   int64
#  18  AGE1824_TOT      3048 non-null   int64
#  19  AGE1824_MALE     3048 non-null   int64
#  20  AGE1824_FEM      3048 non-null   int64
#  21  AGE16PLUS_TOT    3048 non-null   int64
#  22  AGE16PLUS_MALE   3048 non-null   int64
#  23  AGE16PLUS_FEM    3048 non-null   int64
#  24  AGE18PLUS_TOT    3048 non-null   int64
#  25  AGE18PLUS_MALE   3048 non-null   int64
#  26  AGE18PLUS_FEM    3048 non-null   int64
#  27  AGE1544_TOT      3048 non-null   int64
#  28  AGE1544_MALE     3048 non-null   int64
#  29  AGE1544_FEM      3048 non-null   int64
#  30  AGE2544_TOT      3048 non-null   int64
#  31  AGE2544_MALE     3048 non-null   int64
#  32  AGE2544_FEM      3048 non-null   int64
#  33  AGE4564_TOT      3048 non-null   int64
#  34  AGE4564_MALE     3048 non-null   int64
#  35  AGE4564_FEM      3048 non-null   int64
#  36  AGE65PLUS_TOT    3048 non-null   int64
#  37  AGE65PLUS_MALE   3048 non-null   int64
#  38  AGE65PLUS_FEM    3048 non-null   int64
#  39  AGE04_TOT        3048 non-null   int64
#  40  AGE04_MALE       3048 non-null   int64
#  41  AGE04_FEM        3048 non-null   int64
#  42  AGE59_TOT        3048 non-null   int64
#  43  AGE59_MALE       3048 non-null   int64
#  44  AGE59_FEM        3048 non-null   int64
#  45  AGE1014_TOT      3048 non-null   int64
#  46  AGE1014_MALE     3048 non-null   int64
#  47  AGE1014_FEM      3048 non-null   int64
#  48  AGE1519_TOT      3048 non-null   int64
#  49  AGE1519_MALE     3048 non-null   int64
#  50  AGE1519_FEM      3048 non-null   int64
#  51  AGE2024_TOT      3048 non-null   int64
#  52  AGE2024_MALE     3048 non-null   int64
#  53  AGE2024_FEM      3048 non-null   int64
#  54  AGE2529_TOT      3048 non-null   int64
#  55  AGE2529_MALE     3048 non-null   int64
#  56  AGE2529_FEM      3048 non-null   int64
#  57  AGE3034_TOT      3048 non-null   int64
#  58  AGE3034_MALE     3048 non-null   int64
#  59  AGE3034_FEM      3048 non-null   int64
#  60  AGE3539_TOT      3048 non-null   int64
#  61  AGE3539_MALE     3048 non-null   int64
#  62  AGE3539_FEM      3048 non-null   int64
#  63  AGE4044_TOT      3048 non-null   int64
#  64  AGE4044_MALE     3048 non-null   int64
#  65  AGE4044_FEM      3048 non-null   int64
#  66  AGE4549_TOT      3048 non-null   int64
#  67  AGE4549_MALE     3048 non-null   int64
#  68  AGE4549_FEM      3048 non-null   int64
#  69  AGE5054_TOT      3048 non-null   int64
#  70  AGE5054_MALE     3048 non-null   int64
#  71  AGE5054_FEM      3048 non-null   int64
#  72  AGE5559_TOT      3048 non-null   int64
#  73  AGE5559_MALE     3048 non-null   int64
#  74  AGE5559_FEM      3048 non-null   int64
#  75  AGE6064_TOT      3048 non-null   int64
#  76  AGE6064_MALE     3048 non-null   int64
#  77  AGE6064_FEM      3048 non-null   int64
#  78  AGE6569_TOT      3048 non-null   int64
#  79  AGE6569_MALE     3048 non-null   int64
#  80  AGE6569_FEM      3048 non-null   int64
#  81  AGE7074_TOT      3048 non-null   int64
#  82  AGE7074_MALE     3048 non-null   int64
#  83  AGE7074_FEM      3048 non-null   int64
#  84  AGE7579_TOT      3048 non-null   int64
#  85  AGE7579_MALE     3048 non-null   int64
#  86  AGE7579_FEM      3048 non-null   int64
#  87  AGE8084_TOT      3048 non-null   int64
#  88  AGE8084_MALE     3048 non-null   int64
#  89  AGE8084_FEM      3048 non-null   int64
#  90  AGE85PLUS_TOT    3048 non-null   int64
#  91  AGE85PLUS_MALE   3048 non-null   int64
#  92  AGE85PLUS_FEM    3048 non-null   int64
#  93  MEDIAN_AGE_TOT   3048 non-null   float64
#  94  MEDIAN_AGE_MALE  3048 non-null   float64
#  95  MEDIAN_AGE_FEM   3048 non-null   float64
# dtypes: float64(3), int64(91), object(2)
# memory usage: 2.2+ MB

# %%
tx_census_age.head()
# Out:
#    SUMLEV  STATE  COUNTY STNAME          CTYNAME  YEAR  POPESTIMATE  \
# 0      50     48       1  Texas  Anderson County     1        58458
# 1      50     48       1  Texas  Anderson County     2        58452
# 2      50     48       1  Texas  Anderson County     3        58493
# 3      50     48       1  Texas  Anderson County     4        58394
# 4      50     48       1  Texas  Anderson County     5        58059
#
#    POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# 0        35521       22937        3135  ...          757          898
# 1        35518       22934        3135  ...          758          897
# 2        35542       22951        3129  ...          758          903
# 3        35586       22808        3105  ...          751          916
# 4        35327       22732        2999  ...          780          942
#
#    AGE8084_MALE  AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  AGE85PLUS_FEM  \
# 0           349          549            865             298            567
# 1           349          548            865             298            567
# 2           358          545            864             301            563
# 3           368          548            842             294            548
# 4           389          553            851             302            549
#
#    MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 0            39.1             38.8            39.9
# 1            39.1             38.8            39.9
# 2            39.1             38.8            39.9
# 3            39.1             38.7            40.2
# 4            39.2             38.7            40.5
#
# [5 rows x 96 columns]

# %%
tx_census_age.tail()
# Out:
#       SUMLEV  STATE  COUNTY STNAME        CTYNAME  YEAR  POPESTIMATE  \
# 3043      50     48     507  Texas  Zavala County     8        12310
# 3044      50     48     507  Texas  Zavala County     9        12121
# 3045      50     48     507  Texas  Zavala County    10        11957
# 3046      50     48     507  Texas  Zavala County    11        11969
# 3047      50     48     507  Texas  Zavala County    12        11840
#
#       POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# 3043         6211        6099        1050  ...          141          210
# 3044         6126        5995        1001  ...          136          200
# 3045         6051        5906         946  ...          141          194
# 3046         6051        5918         911  ...          154          192
# 3047         6028        5812         847  ...          171          191
#
#       AGE8084_MALE  AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  AGE85PLUS_FEM  \
# 3043            79          131            215              89            126
# 3044            77          123            217              91            126
# 3045            81          113            217              89            128
# 3046            77          115            210              86            124
# 3047            82          109            200              76            124
#
#       MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 3043            30.4             28.5            32.4
# 3044            30.6             28.9            32.5
# 3045            31.1             29.5            32.9
# 3046            31.0             29.5            32.7
# 3047            31.4             29.7            33.4
#
# [5 rows x 96 columns]

# %%
#tried all of the below to drop columns which didn't work but I finally found something that did...

tx_age = pd.concat([tx_census_age.iloc[:,:9],tx_census_age.iloc[:,18:21],tx_census_age.iloc[:,24:27],
                  tx_census_age.iloc[:,36:39],tx_census_age.iloc[:,90:]],axis = 1)

# tx_census_age.drop(tx_census_age.columns[[1]], axis = 1)
# tx_age = tx_census_age.drop(list(range(9,19)), axis = 1)

# tx_census_age.drop(tx_census_age.iloc[:,21:23], axis = 1)
# tx_census_age.drop(tx_census_age.iloc[:,28:35], axis = 1)
# tx_census_age.drop(tx_census_age.iloc[:,38:77], inplace = True, axis = 1)

# %%
tx_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3048 entries, 0 to 3047
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SUMLEV           3048 non-null   int64
#  1   STATE            3048 non-null   int64
#  2   COUNTY           3048 non-null   int64
#  3   STNAME           3048 non-null   object
#  4   CTYNAME          3048 non-null   object
#  5   YEAR             3048 non-null   int64
#  6   POPESTIMATE      3048 non-null   int64
#  7   POPEST_MALE      3048 non-null   int64
#  8   POPEST_FEM       3048 non-null   int64
#  9   AGE1824_TOT      3048 non-null   int64
#  10  AGE1824_MALE     3048 non-null   int64
#  11  AGE1824_FEM      3048 non-null   int64
#  12  AGE18PLUS_TOT    3048 non-null   int64
#  13  AGE18PLUS_MALE   3048 non-null   int64
#  14  AGE18PLUS_FEM    3048 non-null   int64
#  15  AGE65PLUS_TOT    3048 non-null   int64
#  16  AGE65PLUS_MALE   3048 non-null   int64
#  17  AGE65PLUS_FEM    3048 non-null   int64
#  18  AGE85PLUS_TOT    3048 non-null   int64
#  19  AGE85PLUS_MALE   3048 non-null   int64
#  20  AGE85PLUS_FEM    3048 non-null   int64
#  21  MEDIAN_AGE_TOT   3048 non-null   float64
#  22  MEDIAN_AGE_MALE  3048 non-null   float64
#  23  MEDIAN_AGE_FEM   3048 non-null   float64
# dtypes: float64(3), int64(19), object(2)
# memory usage: 571.6+ KB

# %%
tx_age
# Out:
#       SUMLEV  STATE  COUNTY STNAME          CTYNAME  YEAR  POPESTIMATE  \
# 0         50     48       1  Texas  Anderson County     1        58458
# 1         50     48       1  Texas  Anderson County     2        58452
# 2         50     48       1  Texas  Anderson County     3        58493
# 3         50     48       1  Texas  Anderson County     4        58394
# 4         50     48       1  Texas  Anderson County     5        58059
# ...      ...    ...     ...    ...              ...   ...          ...
# 3043      50     48     507  Texas    Zavala County     8        12310
# 3044      50     48     507  Texas    Zavala County     9        12121
# 3045      50     48     507  Texas    Zavala County    10        11957
# 3046      50     48     507  Texas    Zavala County    11        11969
# 3047      50     48     507  Texas    Zavala County    12        11840
#
#       POPEST_MALE  POPEST_FEM  AGE1824_TOT  ...  AGE18PLUS_FEM  AGE65PLUS_TOT  \
# 0           35521       22937         4695  ...          17349           7338
# 1           35518       22934         4695  ...          17347           7339
# 2           35542       22951         4703  ...          17376           7374
# 3           35586       22808         4698  ...          17254           7427
# 4           35327       22732         4636  ...          17230           7653
# ...           ...         ...          ...  ...            ...            ...
# 3043         6211        6099         1515  ...           4247           1617
# 3044         6126        5995         1475  ...           4176           1633
# 3045         6051        5906         1433  ...           4168           1659
# 3046         6051        5918         1413  ...           4180           1690
# 3047         6028        5812         1418  ...           4180           1723
#
#       AGE65PLUS_MALE  AGE65PLUS_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  \
# 0               3391           3947            865             298
# 1               3392           3947            865             298
# 2               3417           3957            864             301
# 3               3444           3983            842             294
# 4               3550           4103            851             302
# ...              ...            ...            ...             ...
# 3043             701            916            215              89
# 3044             718            915            217              91
# 3045             741            918            217              89
# 3046             751            939            210              86
# 3047             768            955            200              76
#
#       AGE85PLUS_FEM  MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 0               567            39.1             38.8            39.9
# 1               567            39.1             38.8            39.9
# 2               563            39.1             38.8            39.9
# 3               548            39.1             38.7            40.2
# 4               549            39.2             38.7            40.5
# ...             ...             ...              ...             ...
# 3043            126            30.4             28.5            32.4
# 3044            126            30.6             28.9            32.5
# 3045            128            31.1             29.5            32.9
# 3046            124            31.0             29.5            32.7
# 3047            124            31.4             29.7            33.4
#
# [3048 rows x 24 columns]

# %% [markdown]
# reading TX census race data

# %%
tx_census_race = pd.read_csv('../data/TX_age_sex_race.csv')

# %% [markdown]
# I'm including these for my own use:
#
#
# The key for the YEAR variable is as follows:
# 1 = 4/1/2010 Census population
# 2 = 4/1/2010 population estimates base
# 3 = 7/1/2010 population estimate
# 4 = 7/1/2011 population estimate
# 5 = 7/1/2012 population estimate
# 6 = 7/1/2013 population estimate
# 7 = 7/1/2014 population estimate
# 8 = 7/1/2015 population estimate
# 9 = 7/1/2016 population estimate
# 10 = 7/1/2017 population estimate
# 11 = 7/1/2018 population estimate
# 12 = 7/1/2019 population estimate
#
#
# The key for AGEGRP is as follows:
# 0 = Total
# 1 = Age 0 to 4 years
# 2 = Age 5 to 9 years
# 3 = Age 10 to 14 years
# 4 = Age 15 to 19 years
# 5 = Age 20 to 24 years
# 6 = Age 25 to 29 years
# 7 = Age 30 to 34 years
# 8 = Age 35 to 39 years
# 9 = Age 40 to 44 years
# 10 = Age 45 to 49 years
# 11 = Age 50 to 54 years
# 12 = Age 55 to 59 years
# 13 = Age 60 to 64 years
# 14 = Age 65 to 69 years
# 15 = Age 70 to 74 years
# 16 = Age 75 to 79 years
# 17 = Age 80 to 84 years
# 18 = Age 85 years or older

# %%
tx_census_race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57912 entries, 0 to 57911
# Data columns (total 80 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SUMLEV        57912 non-null  int64
#  1   STATE         57912 non-null  int64
#  2   COUNTY        57912 non-null  int64
#  3   STNAME        57912 non-null  object
#  4   CTYNAME       57912 non-null  object
#  5   YEAR          57912 non-null  int64
#  6   AGEGRP        57912 non-null  int64
#  7   TOT_POP       57912 non-null  int64
#  8   TOT_MALE      57912 non-null  int64
#  9   TOT_FEMALE    57912 non-null  int64
#  10  WA_MALE       57912 non-null  int64
#  11  WA_FEMALE     57912 non-null  int64
#  12  BA_MALE       57912 non-null  int64
#  13  BA_FEMALE     57912 non-null  int64
#  14  IA_MALE       57912 non-null  int64
#  15  IA_FEMALE     57912 non-null  int64
#  16  AA_MALE       57912 non-null  int64
#  17  AA_FEMALE     57912 non-null  int64
#  18  NA_MALE       57912 non-null  int64
#  19  NA_FEMALE     57912 non-null  int64
#  20  TOM_MALE      57912 non-null  int64
#  21  TOM_FEMALE    57912 non-null  int64
#  22  WAC_MALE      57912 non-null  int64
#  23  WAC_FEMALE    57912 non-null  int64
#  24  BAC_MALE      57912 non-null  int64
#  25  BAC_FEMALE    57912 non-null  int64
#  26  IAC_MALE      57912 non-null  int64
#  27  IAC_FEMALE    57912 non-null  int64
#  28  AAC_MALE      57912 non-null  int64
#  29  AAC_FEMALE    57912 non-null  int64
#  30  NAC_MALE      57912 non-null  int64
#  31  NAC_FEMALE    57912 non-null  int64
#  32  NH_MALE       57912 non-null  int64
#  33  NH_FEMALE     57912 non-null  int64
#  34  NHWA_MALE     57912 non-null  int64
#  35  NHWA_FEMALE   57912 non-null  int64
#  36  NHBA_MALE     57912 non-null  int64
#  37  NHBA_FEMALE   57912 non-null  int64
#  38  NHIA_MALE     57912 non-null  int64
#  39  NHIA_FEMALE   57912 non-null  int64
#  40  NHAA_MALE     57912 non-null  int64
#  41  NHAA_FEMALE   57912 non-null  int64
#  42  NHNA_MALE     57912 non-null  int64
#  43  NHNA_FEMALE   57912 non-null  int64
#  44  NHTOM_MALE    57912 non-null  int64
#  45  NHTOM_FEMALE  57912 non-null  int64
#  46  NHWAC_MALE    57912 non-null  int64
#  47  NHWAC_FEMALE  57912 non-null  int64
#  48  NHBAC_MALE    57912 non-null  int64
#  49  NHBAC_FEMALE  57912 non-null  int64
#  50  NHIAC_MALE    57912 non-null  int64
#  51  NHIAC_FEMALE  57912 non-null  int64
#  52  NHAAC_MALE    57912 non-null  int64
#  53  NHAAC_FEMALE  57912 non-null  int64
#  54  NHNAC_MALE    57912 non-null  int64
#  55  NHNAC_FEMALE  57912 non-null  int64
#  56  H_MALE        57912 non-null  int64
#  57  H_FEMALE      57912 non-null  int64
#  58  HWA_MALE      57912 non-null  int64
#  59  HWA_FEMALE    57912 non-null  int64
#  60  HBA_MALE      57912 non-null  int64
#  61  HBA_FEMALE    57912 non-null  int64
#  62  HIA_MALE      57912 non-null  int64
#  63  HIA_FEMALE    57912 non-null  int64
#  64  HAA_MALE      57912 non-null  int64
#  65  HAA_FEMALE    57912 non-null  int64
#  66  HNA_MALE      57912 non-null  int64
#  67  HNA_FEMALE    57912 non-null  int64
#  68  HTOM_MALE     57912 non-null  int64
#  69  HTOM_FEMALE   57912 non-null  int64
#  70  HWAC_MALE     57912 non-null  int64
#  71  HWAC_FEMALE   57912 non-null  int64
#  72  HBAC_MALE     57912 non-null  int64
#  73  HBAC_FEMALE   57912 non-null  int64
#  74  HIAC_MALE     57912 non-null  int64
#  75  HIAC_FEMALE   57912 non-null  int64
#  76  HAAC_MALE     57912 non-null  int64
#  77  HAAC_FEMALE   57912 non-null  int64
#  78  HNAC_MALE     57912 non-null  int64
#  79  HNAC_FEMALE   57912 non-null  int64
# dtypes: int64(78), object(2)
# memory usage: 35.3+ MB

# %%
tx_census_race.head(20)
# Out:
#     SUMLEV  STATE  COUNTY STNAME          CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0       50     48       1  Texas  Anderson County     1       0    58458
# 1       50     48       1  Texas  Anderson County     1       1     3135
# 2       50     48       1  Texas  Anderson County     1       2     3258
# 3       50     48       1  Texas  Anderson County     1       3     3156
# 4       50     48       1  Texas  Anderson County     1       4     3107
# 5       50     48       1  Texas  Anderson County     1       5     3514
# 6       50     48       1  Texas  Anderson County     1       6     4389
# 7       50     48       1  Texas  Anderson County     1       7     4848
# 8       50     48       1  Texas  Anderson County     1       8     4718
# 9       50     48       1  Texas  Anderson County     1       9     4788
# 10      50     48       1  Texas  Anderson County     1      10     4940
# 11      50     48       1  Texas  Anderson County     1      11     4457
# 12      50     48       1  Texas  Anderson County     1      12     3794
# 13      50     48       1  Texas  Anderson County     1      13     3016
# 14      50     48       1  Texas  Anderson County     1      14     2434
# 15      50     48       1  Texas  Anderson County     1      15     1747
# 16      50     48       1  Texas  Anderson County     1      16     1394
# 17      50     48       1  Texas  Anderson County     1      17      898
# 18      50     48       1  Texas  Anderson County     1      18      865
# 19      50     48       1  Texas  Anderson County     2       0    58452
#
#     TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0      35521       22937  ...       5784         2707        321          129
# 1       1566        1569  ...        385          313         22           27
# 2       1729        1529  ...        375          324         17           16
# 3       1573        1583  ...        283          315         21           17
# 4       1676        1431  ...        324          255          7           12
# 5       2184        1330  ...        530          217         18           13
# 6       3013        1376  ...        728          211         44            5
# 7       3540        1308  ...        814          214         60            7
# 8       3337        1381  ...        607          212         42            5
# 9       3430        1358  ...        598          159         35            5
# 10      3404        1536  ...        426          144         32            2
# 11      2830        1627  ...        283           99         15            5
# 12      2211        1583  ...        170           85          4            5
# 13      1637        1379  ...        114           71          1            0
# 14      1263        1171  ...         77           35          0            7
# 15       844         903  ...         40           18          0            0
# 16       637         757  ...         22           19          2            2
# 17       349         549  ...          5            7          1            1
# 18       298         567  ...          3            9          0            0
# 19     35518       22934  ...       5784         2707        321          129
#
#     HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  HNAC_FEMALE
# 0         182           88        188           34         82           28
# 1          13            9          8            7          3            2
# 2          12           11          1            7          9            5
# 3          11           11          3            3          2            4
# 4          11           13          4            1          2            2
# 5           4            6         16            3          6            3
# 6          13            3         45            2         12            2
# 7          19            4         40            3         20            3
# 8          28           11         24            3          7            2
# 9          25            0         20            0         10            3
# 10         24            4         19            0          9            2
# 11          7            6          6            0          1            0
# 12          4            4          1            1          1            0
# 13          7            2          0            2          0            0
# 14          1            1          0            0          0            0
# 15          1            1          1            1          0            0
# 16          1            0          0            0          0            0
# 17          0            2          0            1          0            0
# 18          1            0          0            0          0            0
# 19        182           88        188           34         82           28
#
# [20 rows x 80 columns]

# %%
tx_census_race.tail()
# Out:
#        SUMLEV  STATE  COUNTY STNAME        CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 57907      50     48     507  Texas  Zavala County    12      14      565
# 57908      50     48     507  Texas  Zavala County    12      15      461
# 57909      50     48     507  Texas  Zavala County    12      16      306
# 57910      50     48     507  Texas  Zavala County    12      17      191
# 57911      50     48     507  Texas  Zavala County    12      18      200
#
#        TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  \
# 57907       272         293  ...        244          263          3
# 57908       203         258  ...        180          240          1
# 57909       135         171  ...        118          153          0
# 57910        82         109  ...         72           99          0
# 57911        76         124  ...         66          112          0
#
#        HBAC_FEMALE  HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  \
# 57907            1          4            4          1            1          1
# 57908            0          4            0          1            1          0
# 57909            0          0            2          0            0          0
# 57910            0          0            0          0            0          0
# 57911            0          1            0          0            1          0
#
#        HNAC_FEMALE
# 57907            1
# 57908            1
# 57909            0
# 57910            0
# 57911            0
#
# [5 rows x 80 columns]

# %%
#creating a table of the census race data I think I need:
tx_race = pd.concat([tx_census_race.iloc[:,:18],tx_census_race.iloc[:,24:26],tx_census_race.iloc[:,28:30],
                  tx_census_race.iloc[:,56:58]],axis = 1)

# %%
tx_race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57912 entries, 0 to 57911
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SUMLEV      57912 non-null  int64
#  1   STATE       57912 non-null  int64
#  2   COUNTY      57912 non-null  int64
#  3   STNAME      57912 non-null  object
#  4   CTYNAME     57912 non-null  object
#  5   YEAR        57912 non-null  int64
#  6   AGEGRP      57912 non-null  int64
#  7   TOT_POP     57912 non-null  int64
#  8   TOT_MALE    57912 non-null  int64
#  9   TOT_FEMALE  57912 non-null  int64
#  10  WA_MALE     57912 non-null  int64
#  11  WA_FEMALE   57912 non-null  int64
#  12  BA_MALE     57912 non-null  int64
#  13  BA_FEMALE   57912 non-null  int64
#  14  IA_MALE     57912 non-null  int64
#  15  IA_FEMALE   57912 non-null  int64
#  16  AA_MALE     57912 non-null  int64
#  17  AA_FEMALE   57912 non-null  int64
#  18  BAC_MALE    57912 non-null  int64
#  19  BAC_FEMALE  57912 non-null  int64
#  20  AAC_MALE    57912 non-null  int64
#  21  AAC_FEMALE  57912 non-null  int64
#  22  H_MALE      57912 non-null  int64
#  23  H_FEMALE    57912 non-null  int64
# dtypes: int64(22), object(2)
# memory usage: 10.6+ MB

# %%
tx_race.head()
# Out:
#    SUMLEV  STATE  COUNTY STNAME          CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50     48       1  Texas  Anderson County     1       0    58458
# 1      50     48       1  Texas  Anderson County     1       1     3135
# 2      50     48       1  Texas  Anderson County     1       2     3258
# 3      50     48       1  Texas  Anderson County     1       3     3156
# 4      50     48       1  Texas  Anderson County     1       4     3107
#
#    TOT_MALE  TOT_FEMALE  ...  IA_MALE  IA_FEMALE  AA_MALE  AA_FEMALE  \
# 0     35521       22937  ...      219        141      245        171
# 1      1566        1569  ...       12          9       17         10
# 2      1729        1529  ...       14          6       15         16
# 3      1573        1583  ...       13         12       11         16
# 4      1676        1431  ...       13         15        5          6
#
#    BAC_MALE  BAC_FEMALE  AAC_MALE  AAC_FEMALE  H_MALE  H_FEMALE
# 0      9346        3633       357         224    6363      2924
# 1       280         357        27          22     418       341
# 2       312         294        22          23     404       348
# 3       278         275        15          22     306       343
# 4       336         253        10          10     345       280
#
# [5 rows x 24 columns]

# %%
tx_race.tail()
# Out:
#        SUMLEV  STATE  COUNTY STNAME        CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 57907      50     48     507  Texas  Zavala County    12      14      565
# 57908      50     48     507  Texas  Zavala County    12      15      461
# 57909      50     48     507  Texas  Zavala County    12      16      306
# 57910      50     48     507  Texas  Zavala County    12      17      191
# 57911      50     48     507  Texas  Zavala County    12      18      200
#
#        TOT_MALE  TOT_FEMALE  ...  IA_MALE  IA_FEMALE  AA_MALE  AA_FEMALE  \
# 57907       272         293  ...        4          3        1          2
# 57908       203         258  ...        3          0        1          1
# 57909       135         171  ...        0          2        1          0
# 57910        82         109  ...        1          0        0          0
# 57911        76         124  ...        1          0        0          1
#
#        BAC_MALE  BAC_FEMALE  AAC_MALE  AAC_FEMALE  H_MALE  H_FEMALE
# 57907         6           3         2           2     252       269
# 57908         1           0         2           2     184       241
# 57909         0           0         1           0     118       154
# 57910         1           0         0           0      72        99
# 57911         0           0         0           1      67       113
#
# [5 rows x 24 columns]
