# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
counties = gpd.read_file('../data/maps/Tx_CntyBndry_Detail_TIGER500k.shp')

# %%
counties.head()
# Out:
#   GEOID10           NAME  POP_2010    AREA_SQKM    AREA_SQMI    LAND_SQKM  \
# 0   48185  Grimes County     26604  2076.143189   801.603038  2039.510046
# 1   48189    Hale County     36273  2602.362403  1004.777329  2602.115719
# 2   48191    Hall County      3353  2341.599958   904.096427  2288.233552
# 3   48199  Hardin County     54635  2324.650383   897.552162  2306.558884
# 4   48201  Harris County   4092459  4603.658575  1777.481783  4411.986582
#
#    WATER_SQKM    LAND_SQMI  WATER_SQMI STATE_NAME STATE_ABBR STATEFIPS  \
# 0   36.633143   787.458908   14.144130      Texas         TX        48
# 1    0.246684  1004.682083    0.095245      Texas         TX        48
# 2   53.366406   883.491551   20.604876      Texas         TX        48
# 3   18.091499   890.566998    6.985164      Texas         TX        48
# 4  191.671993  1703.476843   74.004940      Texas         TX        48
#
#    COUNTY  Shape_Leng  Shape_Area CNTY_FIPS  \
# 0  Grimes    2.360324    0.195162       185
# ...

# %%
counties.plot();

# %%
fig, ax = plt.subplots(figsize=(20,6))
counties.plot(ax = ax)
ax.axis('off');
